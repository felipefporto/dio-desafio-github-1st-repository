# %%
#Importando a Biblioteca Pandas
import pandas as pd

# %%
#dataframe
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Cusro_Python_Pandas_Digital_Innovation-master/datasets/Gapminder.csv",  error_bad_lines=False, sep=";")

# %%
#Visualizando as 5 primeiras linhas
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df = df.rename(columns={"country":"Pais", "continet":"continente", "year":"ano", "lifeExp":"Expectativa de Vida", "pop":"Pop Total", "gdpPercap":"PIB"})

# %%
df.head()

# %%
#Visualizando as 10 primeiras linhas
df.head(10)

# %%
#Total de linhas e colunas
df.shape

# %%
df.columns

# %%
#Retorna o tipo de dados
df.dtypes

# %%
#Mostra as ultimas 5 linhas
df.tail()

# %%
#Retorna informacoes estatisticas
df.describe()

# %%
#Fazendo filtros, slices
df["continente"].unique()

# %%
#Filtrando informacoes apenas de um continente
oceania = df.loc[df["continente"] == "Oceania"]
oceania.head()

# %%
oceania["continente"].unique()

# %%
#Fazendo a contagem dos Pais para cada continente
df.groupby("continente")["Pais"].nunique()

# %%
#Para cada ano qual era a expectativa de vida media
df.groupby("ano")["Expectativa de Vida"].mean()

# %%
df["PIB"].mean()

# %%
df["PIB"].sum()
