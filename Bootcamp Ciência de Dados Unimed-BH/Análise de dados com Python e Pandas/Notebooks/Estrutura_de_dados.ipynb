# %% [markdown]
# **Curso Python Para Análise de dados**

# %% [markdown]
# **Estrutura de dados**

# %% [markdown]
# **Listas**

# %%
#Criando uma lista chamada de animais
animais = ["Gato","Cachorro","Pássaro"]
animais
# Out:
# ['Gato', 'Cachorro', 'Pássaro']

# %%
animais = ["cachorro", "gato", 12345, 6.5]
animais
# Out:
# ['cachorro', 'gato', 12345, 6.5]

# %%
#Imprimindo os primeiros elementos da lista
animais[0]
# Out:
# 'cachorro'

# %%
#Imprimindo o 4 elemento da lista
animais[3]
# Out:
# 6.5

# %%
#Substituindo o primeiro elemento da lista
animais[0] = "Ologbo"

# %%
animais
# Out:
# ['Ologbo', 'Cachorro', 'Pássaro']

# %%
#Removendo gato da lista
animais.remove("Cachorro")

# %%
animais
# Out:
# ['Ologbo', 'Pássaro']

# %%
len(animais)
# Out:
# 2

# %%
"gato" in animais
# Out:
# False

# %%
lista = [500, 30, 300, 80, 10]

# %%
#Retorna o valor máximo da lista
max(lista)
# Out:
# 500

# %%
#Retorna o valor mínimo da lista
min(lista)
# Out:
# 10

# %%
animais.append(["Tigre", "Maritaca"])

# %%
animais
# Out:
# ['cachorro', 'gato', 12345, 6.5, ['leão', 'Cachorro'], ['Tigre', 'Maritaca']]

# %%
animais.extend(["Serpente", 6])

# %%
animais
# Out:
# ['cachorro',
#  'gato',
#  12345,
#  6.5,
#  ['leão', 'Cachorro'],
#  ['Tigre', 'Maritaca'],
#  'Serpente',
#  6]

# %%
animais.count("leão")
# Out:
# 0

# %%
lista.sort()

# %%
lista
# Out:
# [10, 30, 80, 300, 500]

# %% [markdown]
# # **Tuplas**

# %%
#As tuplas usam parênteses como sintaxe (importante deixar ultimo elemento com ,)
tp = ("Ogun", "Oxóssi", 10, 50,)

# %%
#Retornando o último elemento
tp[-1]
# Out:
# 50

# %%
#Diferente das listas as tuplas são imutáveis, o que quer dizer que não podemos alterar os seus elementos
tp[0] = "Laranja"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-9264cd18bf8a> in <module>
#       1 #Diferente das listas as tuplas são imutáveis, o que quer dizer que não podemos alterar os seus elementos
# ----> 2 tp[0] = "Laranja"
#
# TypeError: 'tuple' object does not support item assignment

# %%
#Realizando a contagem de um elemento
tp.count("Ogun")
# Out:
# 1

# %%
tp[0:2]
# Out:
# ('Ogun', 'Oxóssi')

# %% [markdown]
# # **Dicionários**

# %%
#Para criação de dicionários utiliza-se {}
dc = {"Maçã":20, "Banana":10, "Laranja":15, "Uva":5} #Dicionários trabalham com o condeito chave e valor

# %%
dc
# Out:
# {'Maçã': 20, 'Banana': 10, 'Laranja': 15, 'Uva': 5}

# %%
#Acessando o valor de um dicionário através da chave
dc["Maçã"]
# Out:
# 20

# %%
#Atualizando o valor da Maçã
dc["Maçã"] = 25
dc
# Out:
# {'Maçã': 25, 'Banana': 10, 'Laranja': 15, 'Uva': 5}

# %%
#Retornando todas as chaves do dicionário
dc.keys()
# Out:
# dict_keys(['Maçã', 'Banana', 'Laranja', 'Uva'])

# %%
#Retornando os valores do dicionário
dc.values()
# Out:
# dict_values([25, 10, 15, 5])

# %%
#Verificando se já existe uma chave no dicionário e caso não exista inserir
dc.setdefault("Limão", 22)
# Out:
# 22

# %%
dc
# Out:
# {'Maçã': 25, 'Banana': 10, 'Laranja': 15, 'Uva': 5, 'Limão': 22}
